# %% [markdown]
# <a href="https://colab.research.google.com/github/PeterMamdouh678/SP-500/blob/main/Getting_and_filtering_S%26P_500_companies_from_wiki.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

def load_data():
  url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
  html = pd.read_html(url, header = 0)
  df = html[0]
  return df

# %%
df = load_data()
df
# Out:
#     Symbol       Security SEC filings             GICS Sector  \
# 0      MMM             3M     reports             Industrials
# 1      AOS    A. O. Smith     reports             Industrials
# 2      ABT         Abbott     reports             Health Care
# 3     ABBV         AbbVie     reports             Health Care
# 4     ABMD        Abiomed     reports             Health Care
# ..     ...            ...         ...                     ...
# 499    YUM    Yum! Brands     reports  Consumer Discretionary
# 500   ZBRA          Zebra     reports  Information Technology
# 501    ZBH  Zimmer Biomet     reports             Health Care
# 502   ZION  Zions Bancorp     reports              Financials
# 503    ZTS         Zoetis     reports             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota
# 1                     Building Products     Milwaukee, Wisconsin
# 2                 Health Care Equipment  North Chicago, Illinois
# 3                       Pharmaceuticals  North Chicago, Illinois
# 4                 Health Care Equipment   Danvers, Massachusetts
# ..                                  ...                      ...
# 499                         Restaurants     Louisville, Kentucky
# 500  Electronic Equipment & Instruments   Lincolnshire, Illinois
# 501               Health Care Equipment          Warsaw, Indiana
# 502                      Regional Banks     Salt Lake City, Utah
# 503                     Pharmaceuticals   Parsippany, New Jersey
#
#     Date first added      CIK      Founded
# 0         1976-08-09    66740         1902
# 1         2017-07-26    91142         1916
# 2         1964-03-31     1800         1888
# 3         2012-12-31  1551152  2013 (1888)
# 4         2018-05-31   815094         1981
# ..               ...      ...          ...
# 499       1997-10-06  1041061         1997
# 500       2019-12-23   877212         1969
# 501       2001-08-07  1136869         1927
# 502       2001-06-22   109380         1873
# 503       2013-06-21  1555280         1952
#
# [504 rows x 9 columns]

# %% [markdown]
# # **Examining the sectors**

# %%
sector_unique = df['GICS Sector'].unique()
sector_unique
# Out:
# array(['Industrials', 'Health Care', 'Information Technology',
#        'Communication Services', 'Consumer Staples',
#        'Consumer Discretionary', 'Utilities', 'Financials', 'Materials',
#        'Real Estate', 'Energy'], dtype=object)

# %%
len(sector_unique)
# Out:
# 11

# %% [markdown]
# # **Group by sector**

# %%
sector = df.groupby('GICS Sector')

# %%
sector.first()
# Out:
#                        Symbol             Security SEC filings  \
# GICS Sector
# Communication Services   ATVI  Activision Blizzard     reports
# Consumer Discretionary    AAP   Advance Auto Parts     reports
# Consumer Staples          ADM                  ADM     reports
# Energy                    APA      APA Corporation     reports
# Financials                AFL                Aflac     reports
# Health Care               ABT               Abbott     reports
# Industrials               MMM                   3M     reports
# Information Technology    ACN            Accenture     reports
# Materials                 APD         Air Products     reports
# Real Estate               ARE           Alexandria     reports
# Utilities                 AES                  AES     reports
#
#                                                    GICS Sub-Industry  \
# GICS Sector
# Communication Services                Interactive Home Entertainment
# Consumer Discretionary                             Automotive Retail
# Consumer Staples                               Agricultural Products
# Energy                            Oil & Gas Exploration & Production
# Financials                                   Life & Health Insurance
# Health Care                                    Health Care Equipment
# Industrials                                 Industrial Conglomerates
# Information Technology                IT Consulting & Other Services
# Materials                                           Industrial Gases
# Real Estate                                             Office REITs
# Utilities               Independent Power Producers & Energy Traders
#
#                            Headquarters Location Date first added      CIK  \
# GICS Sector
# Communication Services  Santa Monica, California       2015-08-31   718877
# Consumer Discretionary   Raleigh, North Carolina       2015-07-09  1158449
# Consumer Staples               Chicago, Illinois       1981-07-29     7084
# Energy                            Houston, Texas       1997-07-28     6769
# Financials                     Columbus, Georgia       1999-05-28     4977
# Health Care              North Chicago, Illinois       1964-03-31     1800
# Industrials                Saint Paul, Minnesota       1976-08-09    66740
# Information Technology           Dublin, Ireland       2011-07-06  1467373
# Materials                Allentown, Pennsylvania       1985-04-30     2969
# Real Estate                 Pasadena, California       2017-03-20  1035443
# Utilities                    Arlington, Virginia       1998-10-02   874761
#
#                        Founded
# GICS Sector
# Communication Services    2008
# Consumer Discretionary    1932
# Consumer Staples          1902
# Energy                    1954
# Financials                1955
# Health Care               1888
# Industrials               1902
# Information Technology    1989
# Materials                 1940
# Real Estate               1994
# Utilities                 1981

# %%
sector.describe()
# Out:
#                          CIK                                                   \
#                        count          mean            std      min        25%
# GICS Sector
# Communication Services  26.0  1.094660e+06  521922.541174  18926.0  752994.75
# Consumer Discretionary  60.0  8.658420e+05  459208.678026  27419.0  759791.50
# Consumer Staples        32.0  3.872794e+05  564407.571740   7084.0   24213.00
# Energy                  21.0  7.674384e+05  619023.796823   4447.0   93410.00
# Financials              66.0  6.369112e+05  537329.687765   4962.0   71386.25
# Health Care             65.0  8.220182e+05  527683.613634   1800.0  313616.00
# Industrials             73.0  6.736877e+05  585966.514840   4281.0   77360.00
# Information Technology  74.0  9.209406e+05  510697.316741   2488.0  754287.50
# Materials               28.0  8.369064e+05  699182.236462   2969.0   67840.25
# Real Estate             30.0  8.960744e+05  322166.034436  34903.0  807235.25
# Utilities               29.0  8.402204e+05  467422.045064   4904.0  731802.00
#
#
#                               50%         75%        max
# GICS Sector
# Communication Services  1129179.0  1532807.75  1754301.0
# Consumer Discretionary   921249.0  1161339.25  1590895.0
# Consumer Staples          70615.0   789573.00  1679273.0
# Energy                   858470.0  1163165.00  1701605.0
# Financials               739974.5  1118437.00  1601712.0
# Health Care              879169.0  1099800.00  1821825.0
# Industrials              746515.0  1067701.00  1783180.0
# Information Technology   949462.5  1349367.25  1730168.0
# Materials                915994.5  1419355.00  1755672.0
# Real Estate              918217.0  1052997.75  1393311.0
# Utilities                874761.0  1047862.00  1868275.0

# %% [markdown]
# # **Examine data by sector**

# %%
sector.get_group('Health Care')
# Out:
#     Symbol                      Security SEC filings  GICS Sector  \
# 2      ABT                        Abbott     reports  Health Care
# 3     ABBV                        AbbVie     reports  Health Care
# 4     ABMD                       Abiomed     reports  Health Care
# 13       A          Agilent Technologies     reports  Health Care
# 20    ALGN                         Align     reports  Health Care
# ..     ...                           ...         ...          ...
# 476   VTRS                       Viatris     reports  Health Care
# 485    WAT                        Waters     reports  Health Care
# 489    WST  West Pharmaceutical Services     reports  Health Care
# 501    ZBH                 Zimmer Biomet     reports  Health Care
# 503    ZTS                        Zoetis     reports  Health Care
#
#             GICS Sub-Industry     Headquarters Location Date first added  \
# 2       Health Care Equipment   North Chicago, Illinois       1964-03-31
# 3             Pharmaceuticals   North Chicago, Illinois       2012-12-31
# 4       Health Care Equipment    Danvers, Massachusetts       2018-05-31
# 13      Health Care Equipment   Santa Clara, California       2000-06-05
# 20       Health Care Supplies      San Jose, California       2017-06-19
# ..                        ...                       ...              ...
# 476           Pharmaceuticals  Pittsburgh, Pennsylvania       2004-04-23
# 485  Health Care Distributors    Milford, Massachusetts              NaN
# 489      Health Care Supplies       Exton, Pennsylvania       2020-05-22
# 501     Health Care Equipment           Warsaw, Indiana       2001-08-07
# 503           Pharmaceuticals    Parsippany, New Jersey       2013-06-21
#
#          CIK      Founded
# 2       1800         1888
# 3    1551152  2013 (1888)
# 4     815094         1981
# 13   1090872         1999
# 20   1097149         1997
# ..       ...          ...
# 476  1792044         1961
# 485  1000697         1958
# 489   105770         1923
# 501  1136869         1927
# 503  1555280         1952
#
# [65 rows x 9 columns]

# %% [markdown]
# # **Finance data**

# %%
! pip install yfinance

# %%
import yfinance as yf

# %% [markdown]
# ## List of S&P 500 symbols

# %%
list(df.Symbol	)
# Out:
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ABMD',
#  'ACN',
#  'ATVI',
#  'ADM',
#  'ADBE',
#  'ADP',
#  'AAP',
#  'AES',
#  'AFL',
#  'A',
#  'AIG',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AMD',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AMT',
#  'AWK',
#  'AMP',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'ANTM',
#  'AON',
#  'APA',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ANET',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'AZO',
#  'AVB',
#  'AVY',
#  'BKR',
#  'BALL',
#  'BAC',
#  'BBWI',
#  'BAX',
#  'BDX',
#  'WRB',
#  'BRK.B',
#  'BBY',
#  'BIO',
#  'TECH',
#  'BIIB',
#  'BLK',
#  'BK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BRO',
#  'BF.B',
#  'CHRW',
#  'CDNS',
#  'CZR',
#  'CPT',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CTLT',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'CE',
#  'CNC',
#  'CNP',
#  'CDAY',
#  'CERN',
#  'CF',
#  'CRL',
#  'SCHW',
#  'CHTR',
#  'CVX',
#  'CMG',
#  'CB',
#  'CHD',
#  'CI',
#  'CINF',
#  'CTAS',
#  'CSCO',
#  'C',
#  'CFG',
#  'CTXS',
#  'CLX',
#  'CME',
#  'CMS',
#  'KO',
#  'CTSH',
#  'CL',
#  'CMCSA',
#  'CMA',
#  'CAG',
#  'COP',
#  'ED',
#  'STZ',
#  'CEG',
#  'COO',
#  'CPRT',
#  'GLW',
#  'CTVA',
#  'COST',
#  'CTRA',
#  'CCI',
#  'CSX',
#  'CMI',
#  'CVS',
#  'DHI',
#  'DHR',
#  'DRI',
#  'DVA',
#  'DE',
#  'DAL',
#  'XRAY',
#  'DVN',
#  'DXCM',
#  'FANG',
#  'DLR',
#  'DFS',
#  'DISH',
#  'DIS',
#  'DG',
#  'DLTR',
#  'D',
#  'DPZ',
#  'DOV',
#  'DOW',
#  'DTE',
#  'DUK',
#  'DRE',
#  'DD',
#  'DXC',
#  'EMN',
#  'ETN',
#  'EBAY',
#  'ECL',
#  'EIX',
#  'EW',
#  'EA',
#  'EMR',
#  'ENPH',
#  'ETR',
#  'EOG',
#  'EPAM',
#  'EFX',
#  'EQIX',
#  'EQR',
#  'ESS',
#  'EL',
#  'ETSY',
#  'RE',
#  'EVRG',
#  'ES',
#  'EXC',
#  'EXPE',
#  'EXPD',
#  'EXR',
#  'XOM',
#  'FFIV',
#  'FDS',
#  'FAST',
#  'FRT',
#  'FDX',
#  'FITB',
#  'FRC',
#  'FE',
#  'FIS',
#  'FISV',
#  'FLT',
#  'FMC',
#  'F',
#  'FTNT',
#  'FTV',
#  'FBHS',
#  'FOXA',
#  'FOX',
#  'BEN',
#  'FCX',
#  'AJG',
#  'GRMN',
#  'IT',
#  'GE',
#  'GNRC',
#  'GD',
#  'GIS',
#  'GPC',
#  'GILD',
#  'GL',
#  'GPN',
#  'GM',
#  'GS',
#  'GWW',
#  'HAL',
#  'HIG',
#  'HAS',
#  'HCA',
#  'PEAK',
#  'HSIC',
#  'HSY',
#  'HES',
#  'HPE',
#  'HLT',
#  'HOLX',
#  'HD',
#  'HON',
#  'HRL',
#  'HST',
#  'HWM',
#  'HPQ',
#  'HUM',
#  'HII',
#  'HBAN',
#  'IEX',
#  'IDXX',
#  'ITW',
#  'ILMN',
#  'INCY',
#  'IR',
#  'INTC',
#  'ICE',
#  'IBM',
#  'IP',
#  'IPG',
#  'IFF',
#  'INTU',
#  'ISRG',
#  'IVZ',
#  'IPGP',
#  'IQV',
#  'IRM',
#  'JBHT',
#  'JKHY',
#  'J',
#  'JNJ',
#  'JCI',
#  'JPM',
#  'JNPR',
#  'K',
#  'KEY',
#  'KEYS',
#  'KMB',
#  'KIM',
#  'KMI',
#  'KLAC',
#  'KHC',
#  'KR',
#  'LHX',
#  'LH',
#  'LRCX',
#  'LW',
#  'LVS',
#  'LDOS',
#  'LEN',
#  'LLY',
#  'LNC',
#  'LIN',
#  'LYV',
#  'LKQ',
#  'LMT',
#  'L',
#  'LOW',
#  'LUMN',
#  'LYB',
#  'MTB',
#  'MRO',
#  'MPC',
#  'MKTX',
#  'MAR',
#  'MMC',
#  'MLM',
#  'MAS',
#  'MA',
#  'MTCH',
#  'MKC',
#  'MCD',
#  'MCK',
#  'MDT',
#  'MRK',
#  'FB',
#  'MET',
#  'MTD',
#  'MGM',
#  'MCHP',
#  'MU',
#  'MSFT',
#  'MAA',
#  'MRNA',
#  'MHK',
#  'MOH',
#  'TAP',
#  'MDLZ',
#  'MPWR',
#  'MNST',
#  'MCO',
#  'MS',
#  'MOS',
#  'MSI',
#  'MSCI',
#  'NDAQ',
#  'NTAP',
#  'NFLX',
#  'NWL',
#  'NEM',
#  'NWSA',
#  'NWS',
#  'NEE',
#  'NLSN',
#  'NKE',
#  'NI',
#  'NDSN',
#  'NSC',
#  'NTRS',
#  'NOC',
#  'NLOK',
#  'NCLH',
#  'NRG',
#  'NUE',
#  'NVDA',
#  'NVR',
#  'NXPI',
#  'ORLY',
#  'OXY',
#  'ODFL',
#  'OMC',
#  'OKE',
#  'ORCL',
#  'OGN',
#  'OTIS',
#  'PCAR',
#  'PKG',
#  'PARA',
#  'PH',
#  'PAYX',
#  'PAYC',
#  'PYPL',
#  'PENN',
#  'PNR',
#  'PEP',
#  'PKI',
#  'PFE',
#  'PM',
#  'PSX',
#  'PNW',
#  'PXD',
#  'PNC',
#  'POOL',
#  'PPG',
#  'PPL',
#  'PFG',
#  'PG',
#  'PGR',
#  'PLD',
#  'PRU',
#  'PEG',
#  'PTC',
#  'PSA',
#  'PHM',
#  'PVH',
#  'QRVO',
#  'PWR',
#  'QCOM',
#  'DGX',
#  'RL',
#  'RJF',
#  'RTX',
#  'O',
#  'REG',
#  'REGN',
#  'RF',
#  'RSG',
#  'RMD',
#  'RHI',
#  'ROK',
#  'ROL',
#  'ROP',
#  'ROST',
#  'RCL',
#  'SPGI',
#  'CRM',
#  'SBAC',
#  'SLB',
#  'STX',
#  'SEE',
#  'SRE',
#  'NOW',
#  'SHW',
#  'SBNY',
#  'SPG',
#  'SWKS',
#  'SJM',
#  'SNA',
#  'SEDG',
#  'SO',
#  'LUV',
#  'SWK',
#  'SBUX',
#  'STT',
#  'STE',
#  'SYK',
#  'SIVB',
#  'SYF',
#  'SNPS',
#  'SYY',
#  'TMUS',
#  'TROW',
#  'TTWO',
#  'TPR',
#  'TGT',
#  'TEL',
#  'TDY',
#  'TFX',
#  'TER',
#  'TSLA',
#  'TXN',
#  'TXT',
#  'TMO',
#  'TJX',
#  'TSCO',
#  'TT',
#  'TDG',
#  'TRV',
#  'TRMB',
#  'TFC',
#  'TWTR',
#  'TYL',
#  'TSN',
#  'USB',
#  'UDR',
#  'ULTA',
#  'UAA',
#  'UA',
#  'UNP',
#  'UAL',
#  'UNH',
#  'UPS',
#  'URI',
#  'UHS',
#  'VLO',
#  'VTR',
#  'VRSN',
#  'VRSK',
#  'VZ',
#  'VRTX',
#  'VFC',
#  'VTRS',
#  'V',
#  'VNO',
#  'VMC',
#  'WAB',
#  'WMT',
#  'WBA',
#  'WBD',
#  'WM',
#  'WAT',
#  'WEC',
#  'WFC',
#  'WELL',
#  'WST',
#  'WDC',
#  'WRK',
#  'WY',
#  'WHR',
#  'WMB',
#  'WTW',
#  'WYNN',
#  'XEL',
#  'XYL',
#  'YUM',
#  'ZBRA',
#  'ZBH',
#  'ZION',
#  'ZTS']

# %% [markdown]
# ## Retrieve stock data

# %%
data = yf.download(  # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = list(df.Symbol	),

        # use "period" instead of start/end
        # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
        # (optional, default is '1mo')
        period = "ytd",

        # fetch data by interval (including intraday if period < 60 days)
        # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
        # (optional, default is '1d')
        interval = "1d",

        # group by ticker (to access via data['SPY'])
        # (optional, default is 'column')
        group_by = 'ticker',

        # adjust all OHLC automatically
        # (optional, default is False)
        auto_adjust = True,

        # download pre/post regular market hours data
        # (optional, default is False)
        prepost = True,

        # use threads for mass downloading? (True/False/Integer)
        # (optional, default is True)
        threads = True,

        # proxy URL scheme use use when downloading?
        # (optional, default is None)
        proxy = None
       )
# Out:
# [*********************100%***********************]  504 of 504 completed
#
# 26 Failed downloads:
# - BRK.B: No data found, symbol may be delisted
# - ZION: CircuitBreaker 'redis' is OPEN and does not permit further calls
# - ROP: CircuitBreaker 'redis' is OPEN and does not permit further calls
# - SBUX: CircuitBreaker 'redis' is OPEN and does not permit further calls
# - AMCR: CircuitBreaker 'redis' is OPEN and does not permit further calls
# - ZTS: Error occurred while retrieving timeseries from Redis, keys: [RedisKey [key=ZTS, cluster=finance]]
# - ROL: CircuitBreaker 'redis' is OPEN and does not permit further calls
# - PNR: CircuitBreaker 'redis' is OPEN and does not permit further calls
# - DGX: CircuitBreaker 'redis' is OPEN and does not permit further calls
# - ALGN: CircuitBreaker 'redis' is OPEN and does not permit further calls
# - WAB: CircuitBreaker 'redis' is HALF_OPEN and does not permit further calls
# - BF.B: No data found for this date range, symbol may be delisted
# - ACN: CircuitBreaker 'redis' is OPEN and does not permit further calls
# - XYL: CircuitBreaker 'redis' is OPEN and does not permit further calls
# - AXP: CircuitBreaker 'redis' is OPEN and does not permit further calls
# - WBD: CircuitBreaker 'redis' is OPEN and does not permit further calls
# - AWK: CircuitBreaker 'redis' is OPEN and does not permit further calls
# - MA: CircuitBreaker 'redis' is OPEN and does not permit further calls
# - AZO: CircuitBreaker 'redis' is OPEN and does not permit further calls
# - KO: CircuitBreaker 'redis' is OPEN and does not permit further calls
# - CAT: CircuitBreaker 'redis' is OPEN and does not permit further calls
# - PEG: CircuitBreaker 'redis' is OPEN and does not permit further calls
# - BWA: CircuitBreaker 'redis' is OPEN and does not permit further calls
# - TDG: CircuitBreaker 'redis' is OPEN and does not permit further calls
# - PFG: CircuitBreaker 'redis' is OPEN and does not permit further calls
# - MTB: CircuitBreaker 'redis' is OPEN and does not permit further calls

# %%
data
# Out:
#                   FANG                                               \
#                   Open        High         Low       Close   Volume
# Date
# 2022-01-03  104.591712  109.306991  104.562547  108.733376  2002000
# 2022-01-04  110.162541  116.375043  109.608374  115.888931  4505400
# 2022-01-05  118.008373  120.059763  114.061152  114.829208  3375500
# 2022-01-06  119.534757  120.963925  117.765312  120.215317  3343300
# 2022-01-07  120.555601  121.226437  116.880601  118.144485  2441400
# ...                ...         ...         ...         ...      ...
# 2022-05-31  157.009995  159.690002  150.610001  152.020004  5259000
# 2022-06-01  154.000000  156.389999  150.889999  152.889999  3194600
# 2022-06-02  151.350006  155.699997  149.250000  153.899994  2084900
# 2022-06-03  153.660004  155.720001  153.050003  154.660004  1786900
# 2022-06-06  155.759995  156.860001  153.250000  155.809998  1559700
#
#                    ITW                                               ...  MTB  \
#                   Open        High         Low       Close   Volume  ... High
# Date                                                                 ...
# 2022-01-03  245.919642  246.217970  239.048208  242.120956   839700  ...  NaN
# 2022-01-04  243.632473  247.351603  242.836936  246.198074   797700  ...  NaN
# 2022-01-05  246.635628  248.415630  245.094277  245.253387  1120900  ...  NaN
# 2022-01-06  245.750597  246.874279  243.503202  245.223557   732600  ...  NaN
# 2022-01-07  244.527437  245.989233  244.079952  244.756165   695500  ...  NaN
# ...                ...         ...         ...         ...      ...  ...  ...
# 2022-05-31  204.350006  209.070007  202.580002  208.070007  2172200  ...  NaN
# 2022-06-01  209.419998  209.679993  203.589996  205.979996   817800  ...  NaN
# 2022-06-02  207.520004  209.460007  204.830002  209.259995   483500  ...  NaN
# 2022-06-03  207.570007  208.320007  206.580002  207.830002   514300  ...  NaN
# 2022-06-06  208.339996  209.470001  207.550003  208.169998   458400  ...  NaN
#
#                                         POOL                          \
#            Low Close Adj Close Volume   Open        High         Low
# Date
# 2022-01-03 NaN   NaN       NaN    NaN    NaN         NaN         NaN
# 2022-01-04 NaN   NaN       NaN    NaN    NaN         NaN         NaN
# 2022-01-05 NaN   NaN       NaN    NaN    NaN         NaN         NaN
# 2022-01-06 NaN   NaN       NaN    NaN    NaN         NaN         NaN
# 2022-01-07 NaN   NaN       NaN    NaN    NaN         NaN         NaN
# ...         ..   ...       ...    ...    ...         ...         ...
# 2022-05-31 NaN   NaN       NaN    NaN    NaN         NaN         NaN
# 2022-06-01 NaN   NaN       NaN    NaN    NaN         NaN         NaN
# 2022-06-02 NaN   NaN       NaN    NaN    NaN         NaN         NaN
# 2022-06-03 NaN   NaN       NaN    NaN    NaN         NaN         NaN
# 2022-06-06 NaN   NaN       NaN    NaN  410.0  413.334991  404.399994
#
#
#                  Close    Volume
# Date
# 2022-01-03         NaN       NaN
# 2022-01-04         NaN       NaN
# 2022-01-05         NaN       NaN
# 2022-01-06         NaN       NaN
# 2022-01-07         NaN       NaN
# ...                ...       ...
# 2022-05-31         NaN       NaN
# 2022-06-01         NaN       NaN
# 2022-06-02         NaN       NaN
# 2022-06-03         NaN       NaN
# 2022-06-06  411.609985  318659.0
#
# [107 rows x 2546 columns]

# %% [markdown]
# ## Data subset of query symbol

# %%
data['ABT']
# Out:
#                   Open        High         Low       Close    Volume
# Date
# 2022-01-03  138.388337  138.785358  136.184936  138.001251   6688100
# 2022-01-04  138.457837  138.606710  133.753243  134.755707   8241200
# 2022-01-05  134.140318  136.006278  134.060929  134.150253   5948200
# 2022-01-06  133.991448  135.192415  132.879820  134.130402   5710200
# 2022-01-07  133.872344  135.162620  133.376079  134.547256   4367500
# ...                ...         ...         ...         ...       ...
# 2022-05-31  115.559998  118.089996  114.400002  117.459999  10563500
# 2022-06-01  117.849998  118.000000  114.529999  115.080002   4890200
# 2022-06-02  115.290001  117.610001  113.230003  117.510002   3856600
# 2022-06-03  116.779999  117.550003  116.330002  116.570000   3778200
# 2022-06-06  117.379997  118.230003  116.040001  116.419998   4205600
#
# [107 rows x 5 columns]

# %%
df = pd.DataFrame(data['ABT'].Close)
df['Data'] = df.index
df
# Out:
#                  Close       Data
# Date
# 2022-01-03  138.001251 2022-01-03
# 2022-01-04  134.755707 2022-01-04
# 2022-01-05  134.150253 2022-01-05
# 2022-01-06  134.130402 2022-01-06
# 2022-01-07  134.547256 2022-01-07
# ...                ...        ...
# 2022-05-31  117.459999 2022-05-31
# 2022-06-01  115.080002 2022-06-01
# 2022-06-02  117.510002 2022-06-02
# 2022-06-03  116.570000 2022-06-03
# 2022-06-06  116.419998 2022-06-06
#
# [107 rows x 2 columns]

# %% [markdown]
# ## Plot closing price of query symbol

# %%
import matplotlib.pyplot as plt

plt.fill_between(df.Data , df.Close, color="skyblue", alpha =0.3)
plt.plot(df.Data, df.Close, color="skyblue", alpha = 0.8)
plt.xticks(rotation = 90)
plt.xlabel("Date")
plt.ylabel("Closing Price")
# Out:
# Text(0, 0.5, 'Closing Price')

# %%
def price_plot(symbol):

  df = pd.DataFrame(data[symbol].Close)
  df['Data'] = df.index
  plt.fill_between(df.Data, df.Close, color="skyblue", alpha =0.3)
  plt.plot(df.Data, df.Close, color="skyblue", alpha = 0.8)
  plt.xticks(rotation = 90)
  plt.title(symbol, fontweight='bold')
  plt.xlabel("Date")
  plt.ylabel("Closing Price")

  return plt.show()

# %%
price_plot("AAPL")
